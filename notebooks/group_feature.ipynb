# %%
import pandas as pd
data = pd.read_pickle('data/train_v2.pkl')

# %%
data
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>lineID</th>
#       <th>day</th>
#       <th>pid</th>
#       <th>adFlag</th>
#       <th>availability</th>
#       <th>competitorPrice</th>
#       <th>click</th>
#       <th>basket</th>
#       <th>order</th>
#       <th>price</th>
#       <th>...</th>
#       <th>ZBU</th>
#       <th>ZCR</th>
#       <th>ZGE</th>
#       <th>ZPA</th>
#       <th>count</th>
#       <th>weekDay</th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1</td>
#       <td>6570</td>
#       <td>0</td>
#       <td>2</td>
#       <td>14.600000</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>16.89</td>
#       <td>...</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>1</td>
# ...

# %%
value_counts = data['group'].value_counts()
values = data['group'].unique()
first_chunks = []
for i in values:
    first_chunks.append(i[:2])

# %%
pd.unique(first_chunks)
# Out:
# array(['2F', '1C', '22', '18', '20', '13', '2G', '10', '21', '23', '1A',
#        '17', '24', '1E', '14', '12', '1D', '19', '15', '11', '2E'], dtype=object)

# %%
second_chunks = []
for i in values:
    second_chunks.append(i[3:])
len(pd.unique(second_chunks))
# Out:
# 407

# %%
temp = []
for i in pd.unique(second_chunks):
    if len(i) > 3:
        temp.append(i[3])
print(pd.value_counts(temp))
# Out:
# O    192
# I     41
# S     22
# K     11
# Z      9
# J      3
# dtype: int64

# %%
data['manufacturer']
# Out:
# 84      146079
# 82      111712
# 18      105665
# 52      104694
# 156      89827
# 176      77729
# 105      62011
# 4        55928
# 37       51836
# 1        51017
# 89       48303
# 79       44862
# 47       32082
# 102      30018
# 328      29449
# 41       29176
# 125      28426
# 32       28171
# 101      27092
# 58       26403
# 90       25689
# 123      25573
# 141      24952
# 60       23969
# 17       23944
# 7        23854
# 121      23733
# 56       22428
# 65       22267
# 24       21972
#          ...
# 1043         4
# 807          4
# 920          3
# 906          3
# 912          3
# 981          3
# 706          3
# 720          3
# 799          3
# 681          3
# 1046         3
# 1021         3
# 754          2
# 957          2
# 925          2
# 722          2
# 744          2
# 1053         2
# 1060         2
# 1035         2
# 1058         2
# 886          1
# 899          1
# 1013         1
# 562          1
# 278          1
# 913          1
# ...
